# %%
# Webscrapping file

# %%
from urllib.request import Request
from urllib.request import urlopen
from bs4 import BeautifulSoup

Ds = Request('https://www.guru99.com/machine-learning-interview-questions.html')
Ds.add_header('User-Agent', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:78.0) Gecko/20100101 Firefox/78.0')
Ds.add_header('Accept', 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8')
resp = urlopen(Ds)
raw_html = resp.read()
soup = BeautifulSoup(raw_html, 'html.parser')

# %%
a =soup.find_all('p')

# %%
Ds_q_lst = []
Ds_a_lst = []

# %%
n=len(a)

# %%
for x in range(len(a)):
    print(a[x])
    break
# Out:
# <p><strong>1) What is Machine learning?</strong></p>

# %%
 ans = ""
for x in range(n):
    element = a[x].findChildren("strong" , recursive=False)
    if len(element) > 0:
        
        if len(ans) > 0:
            print(ans)
            Ds_a_lst.append(ans)
            ans=""
        ques = element[0].getText()
        print(ques)
        Ds_q_lst.append(ques)
    else:
        ans = ans + a[x].getText()
print(Ds_a_lst[10])
# Out:
# 1) What is Machine learning?
# Machine learning is a branch of computer science which deals with system programming in order to automatically learn and improve with experience.  For example: Robots are programed so that they can perform the task based on data they gather from sensors. It automatically learns programs from data.
# 2) Mention the difference between Data Mining and Machine learning?
# Machine learning relates with the study, design and development of the algorithms that give computers the capability to learn without being explicitly programmed.  While, data mining can be defined as the process in which the unstructured data tries to extract knowledge or unknown interesting patterns.  During this process machine, learning algorithms are used.
# 3) What is ‘Overfitting’ in Machine learning?
# ...

# %%
Ds_q_lst
# Out:
# ['1) What is Machine learning?',
#  '2) Mention the difference between Data Mining and Machine learning? ',
#  '3) What is ‘Overfitting’ in Machine learning?',
#  '4) Why overfitting happens?',
#  '5) How can you avoid overfitting ?',
#  'cross validation',
#  '6) What is inductive machine learning?',
#  '7) What are the five popular algorithms of Machine Learning?',
#  '8) What are the different Algorithm techniques in Machine Learning?',
#  '9) What are the three stages to build the hypotheses or model in machine learning?',
#  '10) What is the standard approach to supervised learning?',
#  '11) What is ‘Training set’ and ‘Test set’?',
#  '12) List down various approaches for machine learning?',
#  '13) What is not Machine Learning?',
#  '14) Explain what is the function of ‘Unsupervised Learning’?',
#  '15) Explain what is the function of ‘Supervised Learning’?',
#  '16) What is algorithm independent machine learning?',
# ...

# %%
import pandas as pd

Ds_ques = pd.DataFrame(Ds_q_lst,columns=['questions'])
DS_q=Ds_ques.drop([5,7,8,9,12,13,14,15,16,20,47,49,50])
DS_q = DS_q.reset_index()

# %%
DS_q.drop('index',axis='columns', inplace=True)

# %%
DS_q
# Out:
#                                             questions
# 0                        1) What is Machine learning?
# 1   2) Mention the difference between Data Mining ...
# 2       3) What is ‘Overfitting’ in Machine learning?
# 3                         4) Why overfitting happens?
# 4                  5) How can you avoid overfitting ?
# 5              6) What is inductive machine learning?
# 6   10) What is the standard approach to supervise...
# 7          11) What is ‘Training set’ and ‘Test set’?
# 8   17) What is the difference between artificial ...
# 9         18) What is classifier in machine learning?
# 10        19) What are the advantages of Naive Bayes?
# 11                   21) What is Genetic Programming?
# 12  22) What is Inductive Logic Programming in Mac...
# 13   23) What is Model Selection in Machine Learning?
# 14  24) What are the two methods used for the cali...
# 15  25) Which method is frequently used to prevent...
# ...

# %%
Ds_ans = pd.DataFrame(Ds_a_lst,columns=['answers'])

# %%
Ds_ans
# Out:
#                                               answers
# 0   Machine learning is a branch of computer scien...
# 1   Machine learning relates with the study, desig...
# 2   In machine learning, when a statistical model ...
# 3   The possibility of overfitting exists as the c...
# 4   In this technique,  a model is usually given a...
# 5   The inductive machine learning involves the pr...
# 6   The different types of techniques in Machine L...
# 7   The standard approach to supervised learning i...
# 8   In various areas of information science like m...
# 9    The different approaches in Machine Learning are
# 10  Machine learning in where mathematical foundat...
# 11  Designing and developing algorithms according ...
# 12  A classifier in a Machine Learning is a system...
# 13  In Naïve Bayes classifier will converge quicke...
# 14                 Pattern Recognition can be used in
# 15  Genetic programming is one of the two techniqu...
# ...

# %%
DS_ans = Ds_ans.drop([6,9,14,41],axis=0)
DS_ans = DS_ans.reset_index()
DS_ans
# Out:
#     index                                            answers
# 0       0  Machine learning is a branch of computer scien...
# 1       1  Machine learning relates with the study, desig...
# 2       2  In machine learning, when a statistical model ...
# 3       3  The possibility of overfitting exists as the c...
# 4       4  In this technique,  a model is usually given a...
# 5       5  The inductive machine learning involves the pr...
# 6       7  The standard approach to supervised learning i...
# 7       8  In various areas of information science like m...
# 8      10  Machine learning in where mathematical foundat...
# 9      11  Designing and developing algorithms according ...
# 10     12  A classifier in a Machine Learning is a system...
# 11     13  In Naïve Bayes classifier will converge quicke...
# 12     15  Genetic programming is one of the two techniqu...
# 13     16  Inductive Logic Programming (ILP) is a subfiel...
# ...

# %%
DS_ans.drop('index',axis='columns', inplace=True)

# %%
DS_ans
# Out:
#                                               answers
# 0   Machine learning is a branch of computer scien...
# 1   Machine learning relates with the study, desig...
# 2   In machine learning, when a statistical model ...
# 3   The possibility of overfitting exists as the c...
# 4   In this technique,  a model is usually given a...
# 5   The inductive machine learning involves the pr...
# 6   The standard approach to supervised learning i...
# 7   In various areas of information science like m...
# 8   Machine learning in where mathematical foundat...
# 9   Designing and developing algorithms according ...
# 10  A classifier in a Machine Learning is a system...
# 11  In Naïve Bayes classifier will converge quicke...
# 12  Genetic programming is one of the two techniqu...
# 13  Inductive Logic Programming (ILP) is a subfiel...
# 14  The process of selecting models among differen...
# 15  The two methods used for predicting good proba...
# ...

# %%
import pandas as pd
Ds = pd.concat([DS_q,DS_ans],axis = 1)

# %%
Ds
# Out:
#                                             questions  \
# 0                        1) What is Machine learning?
# 1   2) Mention the difference between Data Mining ...
# 2       3) What is ‘Overfitting’ in Machine learning?
# 3                         4) Why overfitting happens?
# 4                  5) How can you avoid overfitting ?
# 5              6) What is inductive machine learning?
# 6   10) What is the standard approach to supervise...
# 7          11) What is ‘Training set’ and ‘Test set’?
# 8   17) What is the difference between artificial ...
# 9         18) What is classifier in machine learning?
# 10        19) What are the advantages of Naive Bayes?
# 11                   21) What is Genetic Programming?
# 12  22) What is Inductive Logic Programming in Mac...
# 13   23) What is Model Selection in Machine Learning?
# 14  24) What are the two methods used for the cali...
# 15  25) Which method is frequently used to prevent...
# ...

# %%
Ds.insert(0, "topic", "Data Science")

# %%
Ds
# Out:
#            topic                                          questions  \
# 0   Data Science                       1) What is Machine learning?
# 1   Data Science  2) Mention the difference between Data Mining ...
# 2   Data Science      3) What is ‘Overfitting’ in Machine learning?
# 3   Data Science                        4) Why overfitting happens?
# 4   Data Science                 5) How can you avoid overfitting ?
# 5   Data Science             6) What is inductive machine learning?
# 6   Data Science  10) What is the standard approach to supervise...
# 7   Data Science         11) What is ‘Training set’ and ‘Test set’?
# 8   Data Science  17) What is the difference between artificial ...
# 9   Data Science        18) What is classifier in machine learning?
# 10  Data Science        19) What are the advantages of Naive Bayes?
# 11  Data Science                   21) What is Genetic Programming?
# 12  Data Science  22) What is Inductive Logic Programming in Mac...
# ...

# %%
Ds.to_csv('Ds.csv')

# %%
ml = Request('https://www.interviewbit.com/machine-learning-interview-questions/')
ml.add_header('User-Agent', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:78.0) Gecko/20100101 Firefox/78.0')
ml.add_header('Accept', 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8')
resp = urlopen(ml)
raw_html = resp.read()
soup = BeautifulSoup(raw_html, 'html.parser')

# %%
heading = soup.find_all("h3")
n=len(heading)
ml_lst = []
#print(len(heading[1].p))

#for element in heading[1].parent.next_siblings:
#    print(element)
for x in range(n): 
    a = str.strip(heading[x].text)
#    print(heading[x].parent.findNext('p'))
    ml_lst.append(a)
    
df = pd.DataFrame(ml_lst, columns =['questions']) 
df = df.drop([0,1,5])
df = df.reset_index()

# %%
df.drop(['index'],axis='columns', inplace=True)

# %%
selector = 'article'

# find elements that contain the data we want
found = soup.select(selector)
n = len(found)
ml_ans_lst = []
for x in range(n): 
    a = str.strip(found[x].text)
    ml_ans_lst.append(a)

ans_df = pd.DataFrame(ml_ans_lst, columns =['answers']) 
ans_df = ans_df.drop([0,1])
ans_df =ans_df.reset_index()
#ans_df.drop(['index'],axis = 'columns',inplace =True)

# %%
ans_df.drop(['index'],axis = 'columns',inplace =True)

# %%
ml = pd.concat([df,ans_df],axis = 1)

# %%
ml
# Out:
#                                             questions  \
# 0             1. Why was Machine Learning Introduced?
# 1   2. What are Different Types of Machine Learnin...
# 2                     3. What is Supervised Learning?
# 3                   4. What is Unsupervised Learning?
# 4                5. What is ‘Naive’ in a Naive Bayes?
# 5                 6. What is PCA? When do you use it?
# 6                  7. Explain SVM Algorithm in Detail
# 7                 8. What are Support Vectors in SVM?
# 8               9. What are Different Kernels in SVM?
# 9                       10. What is Cross-Validation?
# 10              11. What is Bias in Machine Learning?
# 11  12. Explain the Difference Between Classificat...
# 12        13. What is F1 score? How would you use it?
# 13                   14. Define Precision and Recall?
# 14    15. How to Tackle Overfitting and Underfitting?
# 15                      16. What is a Neural Network?
# ...

# %%
ml.insert(0, "topic", "Machine Learning")

# %%
ml
# Out:
#                topic                                          questions  \
# 0   Machine Learning            1. Why was Machine Learning Introduced?
# 1   Machine Learning  2. What are Different Types of Machine Learnin...
# 2   Machine Learning                    3. What is Supervised Learning?
# 3   Machine Learning                  4. What is Unsupervised Learning?
# 4   Machine Learning               5. What is ‘Naive’ in a Naive Bayes?
# 5   Machine Learning                6. What is PCA? When do you use it?
# 6   Machine Learning                 7. Explain SVM Algorithm in Detail
# 7   Machine Learning                8. What are Support Vectors in SVM?
# 8   Machine Learning              9. What are Different Kernels in SVM?
# 9   Machine Learning                      10. What is Cross-Validation?
# 10  Machine Learning              11. What is Bias in Machine Learning?
# 11  Machine Learning  12. Explain the Difference Between Classificat...
# ...

# %%
ml.to_csv('ml.csv')

# %%
ds2 = pd.read_excel(r"data_anoop.xlsx")
ds2 = pd.DataFrame(ds2, columns= ['Questions','Answers'])
ds2
# Out:
#                                 Questions  \
# 0                        Cross-Validation
# 1                 k-fold cross-validation
# 2                Model Evaluation Metrics
# 3                 Classification Accuracy
# 4                        Logarithmic Loss
# ..                                    ...
# 83            Light GBM min_data_in_leaf
# 84  Different Parameters used in CatBoost
# 85               CatBoost loss_function:
# 86                    CatBoost iterations
# 87                 CatBoost learning_rate
#
#                                               Answers
# 0   Cross-validation is a technique that involves ...
# 1   In k-fold cross-validation, we divide the data...
# 2   Model evaluation metrics are required to quant...
# 3   Accuracy is a common evaluation metric for cla...
# 4   Logarithmic loss (logloss) measures the perfor...
# ..                                                ...
# 83  A very small value may cause overfitting.  It ...
# ...

# %%
ds2.rename(columns={'Questions':'questions','Answers':'answers'},inplace=True)

# %%
ds2.insert(0, "topic", "Model validation techniques")

# %%
ds2
# Out:
#                           topic                              questions  \
# 0   Model validation techniques                       Cross-Validation
# 1   Model validation techniques                k-fold cross-validation
# 2   Model validation techniques               Model Evaluation Metrics
# 3   Model validation techniques                Classification Accuracy
# 4   Model validation techniques                       Logarithmic Loss
# ..                          ...                                    ...
# 83  Model validation techniques            Light GBM min_data_in_leaf
# 84  Model validation techniques  Different Parameters used in CatBoost
# 85  Model validation techniques               CatBoost loss_function:
# 86  Model validation techniques                    CatBoost iterations
# 87  Model validation techniques                 CatBoost learning_rate
#
#                                               answers
# 0   Cross-validation is a technique that involves ...
# ...

# %%
from urllib.request import Request
from urllib.request import urlopen
from bs4 import BeautifulSoup

py = Request('https://www.interviewbit.com/python-interview-questions/#freshers')
py.add_header('User-Agent', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:78.0) Gecko/20100101 Firefox/78.0')
py.add_header('Accept', 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8')
resp = urlopen(py)
raw_html = resp.read()
soup = BeautifulSoup(raw_html, 'html.parser')

# %%
import pandas as pd
heading = soup.find_all("h3")
n=len(heading)
nlp_lst = []
for x in range(n): 
    a = str.strip(heading[x].text)
    nlp_lst.append(a)
    
df = pd.DataFrame(nlp_lst, columns =['questions']) 
df = df.drop([0,1,2,6,96])

# %%
df = df.reset_index()

# %%
df.drop(['index'],axis= 'columns',inplace = True)

# %%
selector = 'section > article'

# find elements that contain the data we want
found = soup.select(selector)
n = len(found)
nlp_ans_lst = []
for x in range(n): 
    a = str.strip(found[x].text)
    nlp_ans_lst.append(a)

ans_df = pd.DataFrame(nlp_ans_lst, columns =['answers']) 
ans_df = ans_df.drop([0])

# %%
ans_df = ans_df.reset_index()

# %%
ans_df.drop(['index'],axis='columns',inplace=True)

# %%
ds4 = pd.concat([df,ans_df],axis = 1)
ds4
# Out:
#                                             questions  \
# 0                                  1. What is Python?
# 1           2. What are the benefits of using Python?
# 2            3. What is a dynamically typed language?
# 3                 4. What is an Interpreted language?
# 4           5. What is PEP 8 and why is it important?
# ..                                                ...
# 87  88. Write a Program to solve the given equatio...
# 88  89. Write a Program to match a string that has...
# 89  90. Write a Program to convert date from yyyy-...
# 90  91. Write a Program to combine two different d...
# 91  92. How will you access the dataset of a publi...
#
#                                               answers
# 0   Python is a high-level, interpreted, general-p...
# 1   Python is a general-purpose programming langua...
# 2   Before we understand a dynamically typed langu...
# 3   An Interpreted language executes its statement...
# ...

# %%
ds4.insert(0, "topic", "Python")

# %%
ds4
# Out:
#      topic                                          questions  \
# 0   Python                                 1. What is Python?
# 1   Python          2. What are the benefits of using Python?
# 2   Python           3. What is a dynamically typed language?
# 3   Python                4. What is an Interpreted language?
# 4   Python          5. What is PEP 8 and why is it important?
# ..     ...                                                ...
# 87  Python  88. Write a Program to solve the given equatio...
# 88  Python  89. Write a Program to match a string that has...
# 89  Python  90. Write a Program to convert date from yyyy-...
# 90  Python  91. Write a Program to combine two different d...
# 91  Python  92. How will you access the dataset of a publi...
#
#                                               answers
# 0   Python is a high-level, interpreted, general-p...
# 1   Python is a general-purpose programming langua...
# 2   Before we understand a dynamically typed langu...
# ...

# %%
nlp = Request('https://www.analytixlabs.co.in/blog/nlp-interview-questions/#q1')
nlp.add_header('User-Agent', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:78.0) Gecko/20100101 Firefox/78.0')
nlp.add_header('Accept', 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8')
resp = urlopen(nlp)
raw_html = resp.read()
soup = BeautifulSoup(raw_html, 'html.parser')

# %%
import pandas as pd
heading = soup.find_all("h3")
n=len(heading)
nlp_lst = []
for x in range(n): 
    a = str.strip(heading[x].text)
    nlp_lst.append(a)
    
df = pd.DataFrame(nlp_lst, columns =['questions']) 
df = df.drop([0,78,79,80,81,82])

# %%
df = df.reset_index()

# %%
df.drop(['index'],axis=1,inplace=True)

# %%
selector = 'div > h3 ~ p'

# find elements that contain the data we want
found = soup.select(selector)
n = len(found)
nlp_ans_lst = []
for x in range(n): 
    a = str.strip(found[x].text)
    nlp_ans_lst.append(a)

ans_df = pd.DataFrame(nlp_ans_lst, columns =['answers']) 
ans_df = ans_df.drop([0,48,79,80])

# %%
ans_df = ans_df.reset_index()

# %%
ans_df.drop(['index'],axis=1,inplace=True)

# %%
nlp = pd.concat([df,ans_df],axis = 1)
nlp
# Out:
#                                             questions  \
# 0   1. What is the NLG (Natural Language Generation)?
# 1   2. What is the order of steps in natural langu...
# 2                3. What is signal processing in NLP?
# 3               4. What is pragmatic analysis in NLP?
# 4               5. What is syntactic analysis in NLP?
# ..                                                ...
# 72      74. What are the hidden Markov random fields?
# 73              75. What is a coreference resolution?
# 74                          76. What is PAC learning?
# 75                     77. What is sequence learning?
# 76                    78. What is an ensemble method?
#
#                                               answers
# 0   Natural Language Generation is a part of AI an...
# 1   The order of steps that are to be followed in ...
# 2   Signal processing is a method that enables sof...
# 3   The pragmatic analysis is the process of infor...
# ...

# %%
nlp.insert(0, "topic", "NLP")

# %%
nlp
# Out:
#    topic                                          questions  \
# 0    NLP  1. What is the NLG (Natural Language Generation)?
# 1    NLP  2. What is the order of steps in natural langu...
# 2    NLP               3. What is signal processing in NLP?
# 3    NLP              4. What is pragmatic analysis in NLP?
# 4    NLP              5. What is syntactic analysis in NLP?
# ..   ...                                                ...
# 72   NLP      74. What are the hidden Markov random fields?
# 73   NLP              75. What is a coreference resolution?
# 74   NLP                          76. What is PAC learning?
# 75   NLP                     77. What is sequence learning?
# 76   NLP                    78. What is an ensemble method?
#
#                                               answers
# 0   Natural Language Generation is a part of AI an...
# 1   The order of steps that are to be followed in ...
# 2   Signal processing is a method that enables sof...
# ...

# %%
nlp.to_csv('nlp.csv')

# %% [markdown]
# df1 = pd.DataFrame(Ds, columns = ['questions', 'answers'])
# df2 = pd.DataFrame(ml, columns = ['questions', 'answers'])
# df3 = pd.DataFrame(ds2, columns = ['questions', 'answers'])
# df4 = pd.DataFrame(ds3, columns = ['questions', 'answers'])
# df5 = pd.DataFrame(ds4, columns = ['questions', 'answers'])
# df6 = pd.DataFrame(nlp, columns = ['questions', 'answers'])

# %%
data = pd.concat([Ds,ml,ds2,nlp],axis=0)

# %%
data.shape
# Out:
# (235, 3)

# %%
data
# Out:
#            topic                                          questions  \
# 0   Data Science                       1) What is Machine learning?
# 1   Data Science  2) Mention the difference between Data Mining ...
# 2   Data Science      3) What is ‘Overfitting’ in Machine learning?
# 3   Data Science                        4) Why overfitting happens?
# 4   Data Science                 5) How can you avoid overfitting ?
# ..           ...                                                ...
# 72           NLP      74. What are the hidden Markov random fields?
# 73           NLP              75. What is a coreference resolution?
# 74           NLP                          76. What is PAC learning?
# 75           NLP                     77. What is sequence learning?
# 76           NLP                    78. What is an ensemble method?
#
#                                               answers
# 0   Machine learning is a branch of computer scien...
# ...

# %%
with pd.option_context("display.max_rows", 1000):
    display(data)
# Out:
#                           topic  \
# 0                  Data Science
# 1                  Data Science
# 2                  Data Science
# 3                  Data Science
# 4                  Data Science
# 5                  Data Science
# 6                  Data Science
# 7                  Data Science
# 8                  Data Science
# 9                  Data Science
# 10                 Data Science
# 11                 Data Science
# 12                 Data Science
# 13                 Data Science
# 14                 Data Science
# 15                 Data Science
# 16                 Data Science
# 17                 Data Science
# 18                 Data Science
# 19                 Data Science
# 20                 Data Science
# 21                 Data Science
# 22                 Data Science
# 23                 Data Science
# 24                 Data Science
# 25                 Data Science
# 26                 Data Science
# 27                 Data Science
# ...

# %%
data = data.reset_index()

# %%
data.head()
# Out:
#    index         topic                                          questions  \
# 0      0  Data Science                       1) What is Machine learning?
# 1      1  Data Science  2) Mention the difference between Data Mining ...
# 2      2  Data Science      3) What is ‘Overfitting’ in Machine learning?
# 3      3  Data Science                        4) Why overfitting happens?
# 4      4  Data Science                 5) How can you avoid overfitting ?
#
#                                              answers
# 0  Machine learning is a branch of computer scien...
# 1  Machine learning relates with the study, desig...
# 2  In machine learning, when a statistical model ...
# 3  The possibility of overfitting exists as the c...
# 4  In this technique,  a model is usually given a...

# %%
data.drop(columns=['index'],axis=1,inplace=True)

# %%
data
# Out:
#             topic                                          questions  \
# 0    Data Science                       1) What is Machine learning?
# 1    Data Science  2) Mention the difference between Data Mining ...
# 2    Data Science      3) What is ‘Overfitting’ in Machine learning?
# 3    Data Science                        4) Why overfitting happens?
# 4    Data Science                 5) How can you avoid overfitting ?
# ..            ...                                                ...
# 230           NLP      74. What are the hidden Markov random fields?
# 231           NLP              75. What is a coreference resolution?
# 232           NLP                          76. What is PAC learning?
# 233           NLP                     77. What is sequence learning?
# 234           NLP                    78. What is an ensemble method?
#
#                                                answers
# 0    Machine learning is a branch of computer scien...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   topic      235 non-null    object
#  1   questions  235 non-null    object
#  2   answers    235 non-null    object
# dtypes: object(3)
# memory usage: 5.6+ KB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   topic      235 non-null    object
#  1   questions  235 non-null    object
#  2   answers    235 non-null    object
# dtypes: object(3)
# memory usage: 5.6+ KB

# %%
data.to_csv('data.csv')
